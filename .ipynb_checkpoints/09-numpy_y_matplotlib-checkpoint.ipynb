# %% [markdown]
# # Numpy y Matplotlib

# %%
import numpy as np

# %%
a = np.random.uniform(size=(1000,1))

# %%
a[6]
# Out:
# array([0.98559596])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a)

# %%
plt.show()

# %%
x = np.linspace(-32.0, 32.0, 1024)
y = np.sin(2 * np.pi * x / 32)
plt.plot(x, y, 'r.')
plt.savefig('periodica.png')
plt.show()
